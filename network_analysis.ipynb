# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
M=nx.read_gml("D:\Poojitha\Data_Science_Essentials\\polblogs.gml.txt")

# %%
M.edges()
# Out:
# [(u'tsrightdominion.blogspot.com', u'democraticunderground.com'),
#  (u'tsrightdominion.blogspot.com', u'conservativepunk.com'),
#  (u'tsrightdominion.blogspot.com', u'anncoulter.org'),
#  (u'tsrightdominion.blogspot.com', u'aldaynet.org'),
#  (u'tsrightdominion.blogspot.com', u'gevkaffeegal.typepad.com/the_alliance'),
#  (u'tsrightdominion.blogspot.com', u'coxandforkum.com'),
#  (u'tsrightdominion.blogspot.com', u'wonkette.com'),
#  (u'tsrightdominion.blogspot.com', u'hughhewitt.com'),
#  (u'tsrightdominion.blogspot.com', u'blogsforbush.com'),
#  (u'tsrightdominion.blogspot.com', u'drudgereport.com'),
#  (u'tsrightdominion.blogspot.com', u'blogsagainsthillary.com'),
#  (u'tsrightdominion.blogspot.com', u'rightwingnews.com'),
#  (u'tsrightdominion.blogspot.com', u'scrappleface.com'),
#  (u'tsrightdominion.blogspot.com', u'michellemalkin.com'),
#  (u'tsrightdominion.blogspot.com', u'freerepublic.com'),
#  (u'tsrightdominion.blogspot.com', u'dailykos.com'),
# ...

# %%
print(M.nodes())
# Out:
# [u'tsrightdominion.blogspot.com', u'rightrainbow.com', u'gregpalast.com', u'younglibs.com', u'blotts.org/polilog', u'marylandpolitics.blogspot.com', u'blogitics.com', u'thesakeofargument.com', u'joebrent.blogspot.com', u'thesiliconmind.blogspot.com', u'40ozblog.blogspot.com', u'randomjottings.net', u'sonsoftherepublic.com', u'rightvoices.com', u'americasteen.tk', u'blogs.salon.com/0002874', u'alvintostig.typepad.com', u'notgeniuses.com', u'democratreport.blogspot.com', u'victorhanson.com', u'watdanook.blogspot.com', u'talkleft.com', u'urbanecoinc.com/wordpress1', u'etalkinghead.com', u'hellofromparis.blogspot.com', u'americanmuslim.blogs.com', u'travalex.blogspot.com', u'kicktheleftist.blogspot.com', u'horologium.net', u'atomicairship.com', u'prestoncaldwellblog.blogspot.com', u'antijohnkerry.blogspot.com', u'templeofjennifer.com/blog', u'mathewgross.com/blog', u'nomayo.mu.nu', u'rightcrusade.blogspot.com', u'angrychineseblogger.blog-city.com', u'translucence.org', u'toneofvoice.blog
# ...

# %%
G = nx.Graph()
for u,v,data in M.edges_iter(data=True):
    if G.has_edge(u,v):
        G[u][v]['weight'] += 1
    else:
        G.add_edge(u, v, weight=1)

# %% [markdown]
# 1. Create a nice looking graph of the political blog network

# %%
plt.figure(figsize=(40,40))
pos=nx.spring_layout(G, iterations=500, scale=5, k=.3)
nx.draw_networkx_labels(G,pos,fontsize=8)
font = {'fontname'   : 'Helvetica',
            'color'      : 'k',
            'fontweight' : 'bold',
            'fontsize'   : 14}
plt.title("Political blog network graph", font)


nx.draw_networkx_nodes(G,pos,node_color='b',alpha=0.4)
nx.draw_networkx_edges(G,pos,alpha=0.4,node_size=0,width=1,edge_color='k')
plt.axis('off')
plt.show()

# %% [markdown]
# What are the 10 most influential blogs?

# %%
centrality=nx.eigenvector_centrality(G)

# %%
person_list = []
for node in centrality:
    person_list.append((node,centrality[node]))
    
sorted_person_list = person_list.sort(key=lambda x: x[1])

# %%
sorted_list=sorted(person_list, key=lambda x: x[1], reverse=True)

# %%
sorted_list
# Out:
# [(u'atrios.blogspot.com', 0.1948079793663771),
#  (u'dailykos.com', 0.1608974020523483),
#  (u'washingtonmonthly.com', 0.14653924259836879),
#  (u'digbysblog.blogspot.com', 0.14264369221718307),
#  (u'bodyandsoul.typepad.com', 0.14113489174330363),
#  (u'liberaloasis.com', 0.1395237157110787),
#  (u'tbogg.blogspot.com', 0.13703641699824257),
#  (u'corrente.blogspot.com', 0.12941759274096148),
#  (u'talkingpointsmemo.com', 0.12700519780790956),
#  (u'dneiwert.blogspot.com', 0.12237564692546016),
#  (u'pandagon.net', 0.12183624597295237),
#  (u'billmon.org', 0.11749519874171402),
#  (u'xnerg.blogspot.com', 0.11480053426058823),
#  (u'madkane.com/notable.html', 0.11418196235451712),
#  (u'elayneriggs.blogspot.com', 0.1126455958238381),
#  (u'busybusybusy.com', 0.110244290938897),
#  (u'michaelberube.com', 0.10608176183223589),
#  (u'pacificviews.org', 0.10577419182137969),
#  (u'nielsenhayden.com/electrolite', 0.10552543344289474),
#  (u'instapundit.com', 0.10542786230862619),
# ...

# %%
#top 10 most influential blogs:
sorted_list[0:10]
# Out:
# [(u'atrios.blogspot.com', 0.1948079793663771),
#  (u'dailykos.com', 0.1608974020523483),
#  (u'washingtonmonthly.com', 0.14653924259836879),
#  (u'digbysblog.blogspot.com', 0.14264369221718307),
#  (u'bodyandsoul.typepad.com', 0.14113489174330363),
#  (u'liberaloasis.com', 0.1395237157110787),
#  (u'tbogg.blogspot.com', 0.13703641699824257),
#  (u'corrente.blogspot.com', 0.12941759274096148),
#  (u'talkingpointsmemo.com', 0.12700519780790956),
#  (u'dneiwert.blogspot.com', 0.12237564692546016)]

# %% [markdown]
# What are the 10 least influential blogs?

# %%
#10 least influential blogs
descending_ordered_list=sorted(person_list, key=lambda x: x[1], reverse=False)
descending_ordered_list[0:10]
# Out:
# [(u'thelonedem.com', 1.776325109755965e-72),
#  (u'digital-democrat.blogspot.com', 1.776325109755965e-72),
#  (u'americanworldview.tripod.com/weltansblog', 7.491540638916242e-09),
#  (u'quimundus.modblog.com', 6.682929975006484e-08),
#  (u'batr.org/commentary.html', 6.795517611554005e-07),
#  (u'batr.net', 6.796325594929459e-07),
#  (u'democratvoice.org', 1.0233388204113296e-06),
#  (u'quimundus.squarespace.com', 6.061741218869531e-06),
#  (u'massachusetts-liberal.com', 9.483365235734505e-06),
#  (u'thingsasitis.net', 1.1736249650658606e-05)]
